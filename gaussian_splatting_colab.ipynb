# %% [markdown]
# <a href="https://colab.research.google.com/github/jiawei-jw/hellojiawei/blob/main/gaussian_splatting_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /content/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q /content/gaussian-splatting/submodules/simple-knn

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip tandt_db.zip

# !python train.py -s /content/gaussian-splatting/tandt/train

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/GaussianViewTest.zip
# !unzip GaussianViewTest.zip
# !python render.py -m /content/gaussian-splatting/GaussianViewTest/model
# !ffmpeg -framerate 3 -i /content/gaussian-splatting/GaussianViewTest/model/train/ours_30000/renders/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/renders.mp4
# !ffmpeg -framerate 3 -i /content/gaussian-splatting/GaussianViewTest/model/train/ours_30000/gt/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/gt.mp4 -y
# Out:
# /content
# fatal: destination path 'gaussian-splatting' already exists and is not an empty directory.
# /content/gaussian-splatting
#   Preparing metadata (setup.py) ... done

# %%
# 安装 simple_knn
# %cd /content/gaussian-splatting/submodules/simple-knn
# !pip install .

# 安装 diff-gaussian-rasterization
# %cd /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install .

# 回到主目录
# %cd /content/gaussian-splatting
# Out:
# /content/gaussian-splatting/submodules/simple-knn
# Processing /content/gaussian-splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for simple_knn
#   Running setup.py clean for simple_knn
# Failed to build simple_knn
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (simple_knn)
# /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# Processing /content/gaussian-splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...

# %%
# 1. 安装编译所需的依赖
# !pip install ninja

# 2. 确保 CUDA 环境正确
import os
os.environ["CUDA_HOME"] = "/usr/local/cuda"

# 3. 重新编译 simple_knn
# %cd /content/gaussian-splatting/submodules/simple-knn

# 清理之前的编译缓存
# !rm -rf build
! rm -rf *.egg-info

# 重新安装
# !pip install .  --no-build-isolation

# %cd /content/gaussian-splatting
print("✅ 安装完成！")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 6.9 MB/s eta 0:00:00
# ...
# /content/gaussian-splatting/submodules/simple-knn
# Processing /content/gaussian-splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for simple_knn
#   Running setup.py clean for simple_knn
# Failed to build simple_knn
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (simple_knn)
# /content/gaussian-splatting
# ✅ 安装完成！

# %%
# 备选方案：用 setup.py 直接编译
# %cd /content/gaussian-splatting/submodules/simple-knn

! pip install ninja
# !python setup.py build_ext --inplace
! python setup.py install

# %cd /content/gaussian-splatting
print("✅ 安装完成！")
# Out:
# /content/gaussian-splatting/submodules/simple-knn
# ...
# running build_ext
# W0114 08:23:27.842000 4665 torch/utils/cpp_extension.py:521] The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.6). Most likely this shouldn't be a problem.
# W0114 08:23:27.843000 4665 torch/utils/cpp_extension.py:531] There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
# building 'simple_knn._C' extension
# creating /content/gaussian-splatting/submodules/simple-knn/build/temp.linux-x86_64-cpython-312
# ...
